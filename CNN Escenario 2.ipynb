# %% [markdown]
# <center><h1>Escenarios experimentales Internetworking</h1></center>

# %% [markdown]
# Presentado por: Holger Fernando Catucuamba Nepas <br>
# Fecha: 23/02/2023

# %% [markdown]
# ##  Importación de librerias necesarias

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# ## Cargar el Dataset

# %%
datapath = 'https://raw.githubusercontent.com/hfcatucuamba/proyectoInternetworking/main/Escenario2.csv'
dataframe = pd.read_csv(datapath,low_memory=False)

# %%
dataframe.head()
# Out:
#    Source IP   Source Port  Destination IP   Destination Port   Protocol  \
# 0  10.0.2.15         57188  82.161.239.177                110          6
# 1  10.0.2.15         57188  82.161.239.177                110          6
# 2  10.0.2.15         57188  82.161.239.177                110          6
# 3  10.0.2.15         57188  82.161.239.177                110          6
# 4  10.0.2.15         57188  82.161.239.177                110          6
#
#     Flow Duration   Flow Bytes/s   Flow Packets/s   Flow IAT Mean  \
# 0         7248168   2.112603e+04        29.110804    34515.085714
# 1         5157723   1.052790e+03         3.683796   286540.166667
# 2              41   1.324390e+07     48780.487805       41.000000
# 3         9543565   6.373855e+04        83.930900    11929.456250
# 4         9987537   1.996166e+05       245.806348     4069.900978
#
#     Flow IAT Std  ...   Bwd IAT Min  Active Mean   Active Std   Active Max  \
# 0  273869.262513  ...             7            0            0            0
# 1  878838.525555  ...           451            0            0            0
# 2       0.000000  ...             0            0            0            0
# 3   90072.192523  ...             5            0            0            0
# 4   20365.733229  ...             5            0            0            0
#
#     Active Min  Idle Mean   Idle Std   Idle Max   Idle Min  label
# 0            0          0          0          0          0  AUDIO
# 1            0          0          0          0          0  AUDIO
# 2            0          0          0          0          0  AUDIO
# 3            0          0          0          0          0  AUDIO
# 4            0          0          0          0          0  AUDIO
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Descripción del problema

# %%
dataframe.describe()
# Out:
#         Source Port   Destination Port   Protocol   Flow Duration  \
# count   8044.000000        8044.000000     8044.0    8.044000e+03
# mean   30505.505719       16767.761313        6.0    8.412146e+06
# std    22904.243121       22545.613741        0.0    3.062480e+06
# min      110.000000         110.000000        6.0    2.200000e+01
# 25%      443.000000         443.000000        6.0    8.906492e+06
# 50%    38894.000000         443.000000        6.0    9.965426e+06
# 75%    51024.000000       41994.000000        6.0    9.989334e+06
# max    60740.000000       59708.000000        6.0    1.000000e+07
#
#         Flow Bytes/s   Flow Packets/s   Flow IAT Mean   Flow IAT Std  \
# count   8.044000e+03      8044.000000    8.044000e+03   8.044000e+03
# mean    2.707062e+05       706.836422    1.017038e+05   2.436356e+05
# std     1.420024e+06      4391.154798    3.139844e+05   6.377622e+05
# min     0.000000e+00         0.400114    2.200000e+01   0.000000e+00
# 25%     1.420822e+04        30.586932    4.444811e+03   1.386636e+04
# 50%     2.958675e+04        77.540582    1.291837e+04   2.271775e+04
# 75%     1.687313e+05       225.119918    3.518860e+04   1.512991e+05
# max     2.710256e+07     90909.090909    3.332380e+06   5.771646e+06
#
#         Flow IAT Max   Flow IAT Min  ...   Bwd IAT Max   Bwd IAT Min  \
# count   8.044000e+03    8044.000000  ...  8.044000e+03  8.044000e+03
# mean    1.214898e+06      65.375062  ...  1.139737e+06  5.648311e+04
# std     2.026831e+06    1766.055329  ...  1.918480e+06  5.355551e+05
# min     2.200000e+01   -2255.000000  ...  0.000000e+00 -3.270000e+02
# 25%     9.602900e+04       0.000000  ...  1.004742e+05  3.000000e+00
# 50%     2.264350e+05       8.000000  ...  2.169705e+05  2.300000e+01
# 75%     1.362727e+06      19.000000  ...  1.223241e+06  1.890000e+02
# max     9.996903e+06  127791.000000  ...  9.996903e+06  9.996903e+06
#
#         Active Mean   Active Std    Active Max    Active Min     Idle Mean  \
# count  8.044000e+03       8044.0  8.044000e+03  8.044000e+03  8.044000e+03
# mean   4.885837e+04          0.0  4.885837e+04  4.885837e+04  5.060547e+05
# std    3.198387e+05          0.0  3.198387e+05  3.198387e+05  1.884005e+06
# min    0.000000e+00          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# max    4.823748e+06          0.0  4.823748e+06  4.823748e+06  9.996903e+06
#
#         Idle Std      Idle Max      Idle Min
# count     8044.0  8.044000e+03  8.044000e+03
# mean         0.0  5.060547e+05  5.060547e+05
# std          0.0  1.884005e+06  1.884005e+06
# min          0.0  0.000000e+00  0.000000e+00
# 25%          0.0  0.000000e+00  0.000000e+00
# 50%          0.0  0.000000e+00  0.000000e+00
# 75%          0.0  0.000000e+00  0.000000e+00
# max          0.0  9.996903e+06  9.996903e+06
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Normalizar los datos

# %%
def dfNormalize(df):
    for feature_name in df.columns:
        df.loc[:,feature_name]= pd.to_numeric(df.loc[:,feature_name], errors='coerce').fillna(0)
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()   
        if (max_value - min_value) > 0:
            df.loc[:,feature_name] = (df.loc[:,feature_name] - min_value) / (max_value - min_value)
        else:
            df.loc[:,feature_name] = (df.loc[:,feature_name]- min_value)    
    return df

# %%
print (dataframe.shape)
dataframe = dataframe.reindex(np.random.permutation(dataframe.index)).copy()
print(dataframe.describe())
print (list(dataframe))
# Out:
# (8044, 29)
#         Source Port   Destination Port   Protocol   Flow Duration  \
# count   8044.000000        8044.000000     8044.0    8.044000e+03
# mean   30505.505719       16767.761313        6.0    8.412146e+06
# std    22904.243121       22545.613741        0.0    3.062480e+06
# min      110.000000         110.000000        6.0    2.200000e+01
# 25%      443.000000         443.000000        6.0    8.906492e+06
# 50%    38894.000000         443.000000        6.0    9.965426e+06
# 75%    51024.000000       41994.000000        6.0    9.989334e+06
# max    60740.000000       59708.000000        6.0    1.000000e+07
#
#         Flow Bytes/s   Flow Packets/s   Flow IAT Mean   Flow IAT Std  \
# count   8.044000e+03      8044.000000    8.044000e+03   8.044000e+03
# mean    2.707062e+05       706.836422    1.017038e+05   2.436356e+05
# std     1.420024e+06      4391.154798    3.139844e+05   6.377622e+05
# min     0.000000e+00         0.400114    2.200000e+01   0.000000e+00
# 25%     1.420822e+04        30.586932    4.444811e+03   1.386636e+04
# 50%     2.958675e+04        77.540582    1.291837e+04   2.271775e+04
# 75%     1.687313e+05       225.119918    3.518860e+04   1.512991e+05
# max     2.710256e+07     90909.090909    3.332380e+06   5.771646e+06
#
#         Flow IAT Max   Flow IAT Min  ...   Bwd IAT Max   Bwd IAT Min  \
# count   8.044000e+03    8044.000000  ...  8.044000e+03  8.044000e+03
# mean    1.214898e+06      65.375062  ...  1.139737e+06  5.648311e+04
# std     2.026831e+06    1766.055329  ...  1.918480e+06  5.355551e+05
# min     2.200000e+01   -2255.000000  ...  0.000000e+00 -3.270000e+02
# 25%     9.602900e+04       0.000000  ...  1.004742e+05  3.000000e+00
# 50%     2.264350e+05       8.000000  ...  2.169705e+05  2.300000e+01
# 75%     1.362727e+06      19.000000  ...  1.223241e+06  1.890000e+02
# max     9.996903e+06  127791.000000  ...  9.996903e+06  9.996903e+06
#
#         Active Mean   Active Std    Active Max    Active Min     Idle Mean  \
# count  8.044000e+03       8044.0  8.044000e+03  8.044000e+03  8.044000e+03
# mean   4.885837e+04          0.0  4.885837e+04  4.885837e+04  5.060547e+05
# std    3.198387e+05          0.0  3.198387e+05  3.198387e+05  1.884005e+06
# min    0.000000e+00          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# max    4.823748e+06          0.0  4.823748e+06  4.823748e+06  9.996903e+06
#
#         Idle Std      Idle Max      Idle Min
# count     8044.0  8.044000e+03  8.044000e+03
# mean         0.0  5.060547e+05  5.060547e+05
# std          0.0  1.884005e+06  1.884005e+06
# min          0.0  0.000000e+00  0.000000e+00
# 25%          0.0  0.000000e+00  0.000000e+00
# 50%          0.0  0.000000e+00  0.000000e+00
# 75%          0.0  0.000000e+00  0.000000e+00
# max          0.0  9.996903e+06  9.996903e+06
#
# [8 rows x 26 columns]
# ['Source IP', ' Source Port', ' Destination IP', ' Destination Port', ' Protocol', ' Flow Duration', ' Flow Bytes/s', ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min', 'Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Mean', ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Active Mean', ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min', 'label']

# %%
keys = dataframe.keys()
data_to_process = dataframe[keys[4:len(keys) - 1]].copy()
x_normalised = dfNormalize(data_to_process)
print(x_normalised.describe())
# Out:
#         Protocol   Flow Duration   Flow Bytes/s   Flow Packets/s  \
# count     8044.0     8044.000000    8044.000000      8044.000000
# mean         0.0        0.841214       0.009988         0.007771
# std          0.0        0.306249       0.052394         0.048303
# min          0.0        0.000000       0.000000         0.000000
# 25%          0.0        0.890649       0.000524         0.000332
# 50%          0.0        0.996543       0.001092         0.000849
# 75%          0.0        0.998933       0.006226         0.002472
# max          0.0        1.000000       1.000000         1.000000
#
#         Flow IAT Mean   Flow IAT Std   Flow IAT Max   Flow IAT Min  \
# count     8044.000000    8044.000000    8044.000000    8044.000000
# mean         0.030513       0.042212       0.121525       0.017843
# std          0.094223       0.110499       0.202746       0.013580
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.001327       0.002402       0.009604       0.017340
# 50%          0.003870       0.003936       0.022648       0.017402
# 75%          0.010553       0.026214       0.136313       0.017486
# max          1.000000       1.000000       1.000000       1.000000
#
#        Fwd IAT Mean   Fwd IAT Std  ...   Bwd IAT Max   Bwd IAT Min  \
# count   8044.000000   8044.000000  ...   8044.000000   8044.000000
# mean       0.021701      0.043462  ...      0.114009      0.005683
# std        0.069216      0.112640  ...      0.191907      0.053570
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        0.001010      0.002196  ...      0.010051      0.000033
# 50%        0.002857      0.003839  ...      0.021704      0.000035
# 75%        0.008149      0.026423  ...      0.122362      0.000052
# max        1.000000      1.000000  ...      1.000000      1.000000
#
#        Active Mean   Active Std   Active Max   Active Min    Idle Mean  \
# count  8044.000000       8044.0  8044.000000  8044.000000  8044.000000
# mean      0.010129          0.0     0.010129     0.010129     0.050621
# std       0.066305          0.0     0.066305     0.066305     0.188459
# min       0.000000          0.0     0.000000     0.000000     0.000000
# 25%       0.000000          0.0     0.000000     0.000000     0.000000
# 50%       0.000000          0.0     0.000000     0.000000     0.000000
# 75%       0.000000          0.0     0.000000     0.000000     0.000000
# max       1.000000          0.0     1.000000     1.000000     1.000000
#
#         Idle Std     Idle Max     Idle Min
# count     8044.0  8044.000000  8044.000000
# mean         0.0     0.050621     0.050621
# std          0.0     0.188459     0.188459
# min          0.0     0.000000     0.000000
# 25%          0.0     0.000000     0.000000
# 50%          0.0     0.000000     0.000000
# 75%          0.0     0.000000     0.000000
# max          0.0     1.000000     1.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ## Preprocesa los datos dividiendo las características (features) y etiquetas (labels) y convirtiendo las etiquetas a valores numéricos.

# %%
y = dataframe['label']
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_normalised,
                                            y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Crear Modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    Conv1D(64, 3, input_shape=(X_train.shape[1], 1), padding="same", activation="relu", kernel_constraint=MaxNorm(3)),
    Dropout(0.3),
    Conv1D(64, 3, padding="same", activation="relu", kernel_constraint=MaxNorm(3)),
    Flatten(),
    Dense(512, activation="relu", kernel_constraint=MaxNorm(3)),
    Dropout(0.3),
    Dense(10, activation="softmax")
])

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy", 
              metrics=["sparse_categorical_accuracy"])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 24, 64)            256
#
#  dropout (Dropout)           (None, 24, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 24, 64)            12352
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 804,682
# Trainable params: 804,682
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 32
steps_per_epoch = (X_train.shape[0]//batch_size)
validation_steps = (x_normalised.shape[0] // batch_size)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)

# %%
# %%time

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=35, batch_size=32)
# Out:
# Epoch 1/35
# 176/176 [==============================] - 3s 10ms/step - loss: 1.5266 - sparse_categorical_accuracy: 0.4410 - val_loss: 1.3201 - val_sparse_categorical_accuracy: 0.5145
# Epoch 2/35
# 176/176 [==============================] - 2s 9ms/step - loss: 1.3046 - sparse_categorical_accuracy: 0.5188 - val_loss: 1.2054 - val_sparse_categorical_accuracy: 0.5742
# Epoch 3/35
# 176/176 [==============================] - 2s 9ms/step - loss: 1.2270 - sparse_categorical_accuracy: 0.5549 - val_loss: 1.1494 - val_sparse_categorical_accuracy: 0.6421
# Epoch 4/35
# 176/176 [==============================] - 2s 9ms/step - loss: 1.1509 - sparse_categorical_accuracy: 0.5918 - val_loss: 1.0538 - val_sparse_categorical_accuracy: 0.6632
# Epoch 5/35
# 176/176 [==============================] - 2s 9ms/step - loss: 1.0883 - sparse_categorical_accuracy: 0.6277 - val_loss: 1.0091 - val_sparse_categorical_accuracy: 0.6765
# Epoch 6/35
# 176/176 [==============================] - 2s 10ms/step - loss: 1.0477 - sparse_categorical_accuracy: 0.6467 - val_loss: 0.9931 - val_sparse_categorical_accuracy: 0.6806
# Epoch 7/35
# 176/176 [==============================] - 2s 10ms/step - loss: 1.0146 - sparse_categorical_accuracy: 0.6520 - val_loss: 0.9463 - val_sparse_categorical_accuracy: 0.6968
# Epoch 8/35
# 176/176 [==============================] - 2s 10ms/step - loss: 0.9859 - sparse_categorical_accuracy: 0.6577 - val_loss: 0.9252 - val_sparse_categorical_accuracy: 0.7001
# Epoch 9/35
# 176/176 [==============================] - 2s 10ms/step - loss: 0.9560 - sparse_categorical_accuracy: 0.6680 - val_loss: 0.9175 - val_sparse_categorical_accuracy: 0.7001
# Epoch 10/35
# 176/176 [==============================] - 2s 10ms/step - loss: 0.9355 - sparse_categorical_accuracy: 0.6755 - val_loss: 0.9151 - val_sparse_categorical_accuracy: 0.6964
# Epoch 11/35
# 176/176 [==============================] - 2s 10ms/step - loss: 0.9169 - sparse_categorical_accuracy: 0.6750 - val_loss: 0.8802 - val_sparse_categorical_accuracy: 0.7034
# Epoch 12/35
# 176/176 [==============================] - 2s 10ms/step - loss: 0.9042 - sparse_categorical_accuracy: 0.6819 - val_loss: 0.8272 - val_sparse_categorical_accuracy: 0.7179
# Epoch 13/35
# 176/176 [==============================] - 2s 10ms/step - loss: 0.8903 - sparse_categorical_accuracy: 0.6858 - val_loss: 0.8660 - val_sparse_categorical_accuracy: 0.7133
# Epoch 14/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.8839 - sparse_categorical_accuracy: 0.6881 - val_loss: 0.8163 - val_sparse_categorical_accuracy: 0.7204
# Epoch 15/35
# 176/176 [==============================] - 2s 10ms/step - loss: 0.8555 - sparse_categorical_accuracy: 0.6934 - val_loss: 0.8294 - val_sparse_categorical_accuracy: 0.7104
# Epoch 16/35
# 176/176 [==============================] - 2s 10ms/step - loss: 0.8557 - sparse_categorical_accuracy: 0.6968 - val_loss: 0.8078 - val_sparse_categorical_accuracy: 0.7200
# Epoch 17/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.8262 - sparse_categorical_accuracy: 0.7041 - val_loss: 0.7907 - val_sparse_categorical_accuracy: 0.7225
# Epoch 18/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.8206 - sparse_categorical_accuracy: 0.7032 - val_loss: 0.7762 - val_sparse_categorical_accuracy: 0.7328
# Epoch 19/35
# 176/176 [==============================] - 2s 12ms/step - loss: 0.8086 - sparse_categorical_accuracy: 0.7075 - val_loss: 0.7513 - val_sparse_categorical_accuracy: 0.7419
# Epoch 20/35
# 176/176 [==============================] - 2s 12ms/step - loss: 0.7996 - sparse_categorical_accuracy: 0.7149 - val_loss: 0.7570 - val_sparse_categorical_accuracy: 0.7357
# Epoch 21/35
# 176/176 [==============================] - 2s 12ms/step - loss: 0.7893 - sparse_categorical_accuracy: 0.7171 - val_loss: 0.7503 - val_sparse_categorical_accuracy: 0.7312
# Epoch 22/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7750 - sparse_categorical_accuracy: 0.7181 - val_loss: 0.7347 - val_sparse_categorical_accuracy: 0.7415
# Epoch 23/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7792 - sparse_categorical_accuracy: 0.7201 - val_loss: 0.7219 - val_sparse_categorical_accuracy: 0.7403
# Epoch 24/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7640 - sparse_categorical_accuracy: 0.7215 - val_loss: 0.7118 - val_sparse_categorical_accuracy: 0.7510
# Epoch 25/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7588 - sparse_categorical_accuracy: 0.7250 - val_loss: 0.7171 - val_sparse_categorical_accuracy: 0.7444
# Epoch 26/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7506 - sparse_categorical_accuracy: 0.7245 - val_loss: 0.7061 - val_sparse_categorical_accuracy: 0.7543
# Epoch 27/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7471 - sparse_categorical_accuracy: 0.7316 - val_loss: 0.7026 - val_sparse_categorical_accuracy: 0.7457
# Epoch 28/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7514 - sparse_categorical_accuracy: 0.7265 - val_loss: 0.6950 - val_sparse_categorical_accuracy: 0.7597
# Epoch 29/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7212 - sparse_categorical_accuracy: 0.7401 - val_loss: 0.6851 - val_sparse_categorical_accuracy: 0.7655
# Epoch 30/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7198 - sparse_categorical_accuracy: 0.7401 - val_loss: 0.6815 - val_sparse_categorical_accuracy: 0.7564
# Epoch 31/35
# 176/176 [==============================] - 2s 12ms/step - loss: 0.7212 - sparse_categorical_accuracy: 0.7426 - val_loss: 0.7016 - val_sparse_categorical_accuracy: 0.7490
# Epoch 32/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7267 - sparse_categorical_accuracy: 0.7346 - val_loss: 0.6826 - val_sparse_categorical_accuracy: 0.7589
# Epoch 33/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7113 - sparse_categorical_accuracy: 0.7451 - val_loss: 0.6763 - val_sparse_categorical_accuracy: 0.7693
# Epoch 34/35
# 176/176 [==============================] - 2s 11ms/step - loss: 0.7107 - sparse_categorical_accuracy: 0.7458 - val_loss: 0.6799 - val_sparse_categorical_accuracy: 0.7577
# Epoch 35/35
# 176/176 [==============================] - 2s 12ms/step - loss: 0.6965 - sparse_categorical_accuracy: 0.7460 - val_loss: 0.6917 - val_sparse_categorical_accuracy: 0.7519
# Wall time: 1min 6s

# %%
loss, accuracy = model.evaluate(X_test,y_test,batch_size=batch_size)
print('test_loss: %.2f' % (loss * 100.0))  
print('test_accuracy: %.2f' % (accuracy * 100.0))
# Out:
# 76/76 [==============================] - 0s 3ms/step - loss: 0.6917 - sparse_categorical_accuracy: 0.7519
# test_loss: 69.17
# test_accuracy: 75.19

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
model_probs = model.predict(X_test,batch_size=batch_size,verbose=0)
# predict crisp classes for test set
model_classes = np.argmax(model_probs,axis=1)
# reduce to 1d array
model_probs = model_probs[:, 0]
 
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, model_classes)*100
# precision tp / (tp + fp)
precision = precision_score(y_test, model_classes, average='weighted')*100
# recall: tp / (tp + fn)
recall = recall_score(y_test, model_classes, average='weighted')*100
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, model_classes, average='weighted')*100

print('Accuracy: %.2f' % accuracy)
print('F1 score: %.2f' % f1)
print('Precision: %.2f' % precision)
print('Recall: %.2f' % recall)
# Out:
# Accuracy: 75.19
# F1 score: 72.96
# Precision: 74.45
# Recall: 75.19
